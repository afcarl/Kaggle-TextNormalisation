# %%
'''
READ MY COMMENT BELOW
'''
########################################################

import os
import operator
from num2words import num2words
import gc


INPUT_PATH = r''
DATA_INPUT_PATH = r'en_with_types/'
SUBM_PATH = INPUT_PATH

SUB = str.maketrans("₀₁₂₃₄₅₆₇₈₉", "0123456789")
SUP = str.maketrans("⁰¹²³⁴⁵⁶⁷⁸⁹", "0123456789")
OTH = str.maketrans("፬", "4")

# %%
print('Train start...')

file = "en_train.csv"
train = open(os.path.join(INPUT_PATH, "en_train.csv"), encoding='UTF8')
line = train.readline()
res = dict()
total = 0
not_same = 0
while 1:
    line = train.readline().strip()
    if line == '':
        break
    total += 1
    pos = line.find('","')
    text = line[pos + 2:]
    if text[:3] == '","':
        continue
    text = text[1:-1]
    arr = text.split('","')
    if arr[0] != arr[1]:
        not_same += 1
    if arr[0] not in res:
        res[arr[0]] = dict()
        res[arr[0]][arr[1]] = 1
    else:
        if arr[1] in res[arr[0]]:
            res[arr[0]][arr[1]] += 1
        else:
            res[arr[0]][arr[1]] = 1
train.close()
print(file + ':\tTotal: {} Have diff value: {}'.format(total, not_same))
# Out:
# Train start...
# en_train.csv:	Total: 9918441 Have diff value: 659793

# %%
files = os.listdir(DATA_INPUT_PATH)
for file in files:
    train = open(os.path.join(DATA_INPUT_PATH, file), encoding='UTF8')
    while 1:
        line = train.readline().strip()
        if line == '':
            break
        total += 1
        pos = line.find('\t')
        text = line[pos + 1:]
        if text[:3] == '':
            continue
        arr = text.split('\t')
        if arr[0] == '<eos>':
            continue
        if arr[1] != '<self>':
            not_same += 1

        if arr[1] == '<self>' or arr[1] == 'sil':
            arr[1] = arr[0]

        if arr[1] == '<self>' or arr[1] == 'sil':
            arr[1] = arr[0]

        if arr[0] not in res:
            res[arr[0]] = dict()
            res[arr[0]][arr[1]] = 1
        else:
            if arr[1] in res[arr[0]]:
                res[arr[0]][arr[1]] += 1
            else:
                res[arr[0]][arr[1]] = 1
    train.close()
    print(file + ':\tTotal: {} Have diff value: {}'.format(total, not_same))
    gc.collect()

sdict = {}
sdict['km2'] = 'square kilometers'
sdict['km'] = 'kilometers'
sdict['kg'] = 'kilograms'
sdict['lb'] = 'pounds'
sdict['dr'] = 'doctor'
sdict['m²'] = 'square meters'

total = 0
changes = 0
out = open(os.path.join(SUBM_PATH, 'baseline_ext_en.csv'), "w", encoding='UTF8')
out.write('"id","after"\n')
test = open(os.path.join(INPUT_PATH, "en_test.csv"), encoding='UTF8')
line = test.readline().strip()
while 1:
    line = test.readline().strip()
    if line == '':
        break

    pos = line.find(',')
    i1 = line[:pos]
    line = line[pos + 1:]

    pos = line.find(',')
    i2 = line[:pos]
    line = line[pos + 1:]

    line = line[1:-1]
    out.write('"' + i1 + '_' + i2 + '",')
    if line in res:
        srtd = sorted(res[line].items(), key=operator.itemgetter(1), reverse=True)
        out.write('"' + srtd[0][0] + '"')
        changes += 1
    else:
        if len(line) > 1:
            val = line.split(',')
            if len(val) == 2 and val[0].isdigit and val[1].isdigit:
                line = ''.join(val)

        if line.isdigit():
            srtd = line.translate(SUB)
            srtd = srtd.translate(SUP)
            srtd = srtd.translate(OTH)
            out.write('"' + num2words(float(srtd)) + '"')
            changes += 1
        elif len(line.split(' ')) > 1:
            val = line.split(' ')
            for i, v in enumerate(val):
                if v.isdigit():
                    srtd = v.translate(SUB)
                    srtd = srtd.translate(SUP)
                    srtd = srtd.translate(OTH)
                    val[i] = num2words(float(srtd))
                elif v in sdict:
                    val[i] = sdict[v]

            out.write('"' + ' '.join(val) + '"')
            changes += 1
        else:
            out.write('"' + line + '"')

    out.write('\n')
    total += 1

print('Total: {} Changed: {}'.format(total, changes))
test.close()
out.close()
# Out:
# output-00000-of-00100:	Total: 21360490 Have diff value: 3551655
# output-00001-of-00100:	Total: 32825093 Have diff value: 6448115
# output-00002-of-00100:	Total: 44250937 Have diff value: 9339209
# output-00003-of-00100:	Total: 55710374 Have diff value: 12237813
# output-00004-of-00100:	Total: 67101629 Have diff value: 15118941
# output-00005-of-00100:	Total: 78597949 Have diff value: 18021754
# output-00006-of-00100:	Total: 90017596 Have diff value: 20908922
# output-00007-of-00100:	Total: 101460729 Have diff value: 23802888
# output-00008-of-00100:	Total: 112871664 Have diff value: 26689240
# output-00009-of-00100:	Total: 124336086 Have diff value: 29591674
# output-00010-of-00100:	Total: 135767149 Have diff value: 32481594
# output-00011-of-00100:	Total: 147248394 Have diff value: 35387471
# output-00012-of-00100:	Total: 158678088 Have diff value: 38279055
# output-00013-of-00100:	Total: 170055252 Have diff value: 41153557
# output-00014-of-00100:	Total: 181494302 Have diff value: 44042491
# output-00015-of-00100:	Total: 192898205 Have diff value: 46930031
# output-00016-of-00100:	Total: 204276598 Have diff value: 49808406
# output-00017-of-00100:	Total: 215705500 Have diff value: 52698190
# output-00018-of-00100:	Total: 227123356 Have diff value: 55587094
# output-00019-of-00100:	Total: 238523401 Have diff value: 58467958
# output-00020-of-00100:	Total: 249948446 Have diff value: 61355324
# output-00021-of-00100:	Total: 261356109 Have diff value: 64243275
# output-00022-of-00100:	Total: 272815592 Have diff value: 67141790
# output-00023-of-00100:	Total: 284239089 Have diff value: 70030266
# output-00024-of-00100:	Total: 295674425 Have diff value: 72919896
# output-00025-of-00100:	Total: 307099835 Have diff value: 75806513
# output-00026-of-00100:	Total: 318590359 Have diff value: 78714104
# output-00027-of-00100:	Total: 329996040 Have diff value: 81593335
# output-00028-of-00100:	Total: 341429609 Have diff value: 84485394
# output-00029-of-00100:	Total: 352904310 Have diff value: 87387357
# output-00030-of-00100:	Total: 364344432 Have diff value: 90278814
# output-00031-of-00100:	Total: 375755758 Have diff value: 93164385
# output-00032-of-00100:	Total: 387238065 Have diff value: 96068242
# output-00033-of-00100:	Total: 398669297 Have diff value: 98959837
# output-00034-of-00100:	Total: 410099811 Have diff value: 101850299
# output-00035-of-00100:	Total: 421540996 Have diff value: 104742275
# output-00036-of-00100:	Total: 432944897 Have diff value: 107630910
# output-00037-of-00100:	Total: 444340676 Have diff value: 110512389
# output-00038-of-00100:	Total: 455787736 Have diff value: 113408877
# output-00039-of-00100:	Total: 467206448 Have diff value: 116297893
# output-00040-of-00100:	Total: 478670309 Have diff value: 119199386
# output-00041-of-00100:	Total: 490080436 Have diff value: 122086819
# output-00042-of-00100:	Total: 501488924 Have diff value: 124971318
# output-00043-of-00100:	Total: 512942127 Have diff value: 127865433
# output-00044-of-00100:	Total: 524347187 Have diff value: 130750664
# output-00045-of-00100:	Total: 535808196 Have diff value: 133647915
# output-00046-of-00100:	Total: 547245874 Have diff value: 136539603
# output-00047-of-00100:	Total: 558704320 Have diff value: 139433304
# output-00048-of-00100:	Total: 570167767 Have diff value: 142329747
# output-00049-of-00100:	Total: 581619301 Have diff value: 145224427
# output-00050-of-00100:	Total: 593071251 Have diff value: 148122050
# output-00051-of-00100:	Total: 604537459 Have diff value: 151020532
# output-00052-of-00100:	Total: 615922983 Have diff value: 153899534
# output-00053-of-00100:	Total: 627374796 Have diff value: 156796814
# output-00054-of-00100:	Total: 638847899 Have diff value: 159694306
# output-00055-of-00100:	Total: 650259023 Have diff value: 162575442
# output-00056-of-00100:	Total: 661697464 Have diff value: 165467645
# output-00057-of-00100:	Total: 673150874 Have diff value: 168361391
# output-00058-of-00100:	Total: 684594409 Have diff value: 171253595
# output-00059-of-00100:	Total: 696088591 Have diff value: 174162942
# output-00060-of-00100:	Total: 707533817 Have diff value: 177053571
# output-00061-of-00100:	Total: 718983081 Have diff value: 179950199
# output-00062-of-00100:	Total: 730383926 Have diff value: 182837418
# output-00063-of-00100:	Total: 741812057 Have diff value: 185725792
# output-00064-of-00100:	Total: 753249013 Have diff value: 188616889
# output-00065-of-00100:	Total: 764684170 Have diff value: 191510148
# output-00066-of-00100:	Total: 776115841 Have diff value: 194397134
# output-00067-of-00100:	Total: 787554928 Have diff value: 197293393
# output-00068-of-00100:	Total: 798984205 Have diff value: 200182157
# output-00069-of-00100:	Total: 810441582 Have diff value: 203080478
# output-00070-of-00100:	Total: 821873028 Have diff value: 205970696
# output-00071-of-00100:	Total: 833291012 Have diff value: 208855671
# output-00072-of-00100:	Total: 844734948 Have diff value: 211753156
# output-00073-of-00100:	Total: 856127917 Have diff value: 214632639
# output-00074-of-00100:	Total: 867591436 Have diff value: 217526693
# output-00075-of-00100:	Total: 879046165 Have diff value: 220420695
# output-00076-of-00100:	Total: 890494133 Have diff value: 223314243
# output-00077-of-00100:	Total: 901892780 Have diff value: 226197227
# output-00078-of-00100:	Total: 913319368 Have diff value: 229086555
# output-00079-of-00100:	Total: 924823191 Have diff value: 231995937
# output-00080-of-00100:	Total: 936305298 Have diff value: 234898582
# output-00081-of-00100:	Total: 947770201 Have diff value: 237798493
# output-00082-of-00100:	Total: 959209096 Have diff value: 240689439
# output-00083-of-00100:	Total: 970663051 Have diff value: 243584773
# output-00084-of-00100:	Total: 982097087 Have diff value: 246474473
# output-00085-of-00100:	Total: 993513574 Have diff value: 249364748
# output-00086-of-00100:	Total: 1004921734 Have diff value: 252250921
# output-00087-of-00100:	Total: 1016325776 Have diff value: 255135556
# output-00088-of-00100:	Total: 1027790377 Have diff value: 258032010
# output-00089-of-00100:	Total: 1039211324 Have diff value: 260919525
# output-00090-of-00100:	Total: 1050683397 Have diff value: 263818227
# output-00091-of-00100:	Total: 1062139992 Have diff value: 266712769
# output-00092-of-00100:	Total: 1073541949 Have diff value: 269593514
# output-00093-of-00100:	Total: 1084950539 Have diff value: 272478304
# output-00094-of-00100:	Total: 1096367714 Have diff value: 275366984
# output-00095-of-00100:	Total: 1107818273 Have diff value: 278261505
# output-00096-of-00100:	Total: 1119225669 Have diff value: 281145780
# output-00097-of-00100:	Total: 1130684251 Have diff value: 284045996
# output-00098-of-00100:	Total: 1142096671 Have diff value: 286930234
# output-00099-of-00100:	Total: 1153550646 Have diff value: 289823470
# Total: 1088564 Changed: 1088560
